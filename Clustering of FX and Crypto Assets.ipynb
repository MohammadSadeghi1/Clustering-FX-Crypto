# %% [markdown]
# # Clustering of FX and Crypto Assets

# %% [markdown]
# ## Web Scraping & Data Analysis

# %%
import pandas as pd 
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import seaborn as sns

# %%
fx_tickers = ['EURUSD=X', 'CHFUSD=X', 'CADUSD=X', 'AUDUSD=X', 'GBPUSD=X', 'JPYUSD=X']  
cryp_tickers = ['BTC-USD', 'ETH-USD', 'USDT-USD', 'BNB-USD', 'ADA-USD', 'XRP-USD', 
                'DOGE-USD', 'LTC-USD', 'BCH-USD', 'XLM-USD', 'XMR-USD']

# %%
tickers = fx_tickers + cryp_tickers
tickers
# Out:
# ['EURUSD=X',
#  'CHFUSD=X',
#  'CADUSD=X',
#  'AUDUSD=X',
#  'GBPUSD=X',
#  'JPYUSD=X',
#  'BTC-USD',
#  'ETH-USD',
#  'USDT-USD',
#  'BNB-USD',
#  'ADA-USD',
#  'XRP-USD',
#  'DOGE-USD',
#  'LTC-USD',
#  'BCH-USD',
#  'XLM-USD',
#  'XMR-USD']

# %%
start = '2009-01-01'
end = '2022-01-01'

# %%
fx = yf.download(tickers=fx_tickers, start=start, end=end)['Adj Close']
fx
# Out:
# [*********************100%***********************]  6 of 6 completed
#             AUDUSD=X  CADUSD=X  CHFUSD=X  EURUSD=X  GBPUSD=X  JPYUSD=X
# Date
# 2009-01-01  0.705020  0.818465  0.939232  1.399894  1.474100  0.011029
# 2009-01-02  0.709320  0.826856  0.926698  1.392292  1.452391  0.010894
# 2009-01-05  0.714286  0.841751  0.902039  1.364592  1.471605  0.010728
# 2009-01-06  0.720357  0.844523  0.895736  1.351004  1.491202  0.010709
# 2009-01-07  0.710278  0.835981  0.905961  1.361100  1.507909  0.010790
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-27  0.723129  0.780396  1.088399  1.132426  1.340430  0.008746
# 2021-12-28  0.723700  0.782044  1.090322  1.133003  1.344267  0.008711
# 2021-12-29  0.723400  0.780457  1.090631  1.131478  1.343328  0.008713
# 2021-12-30  0.725879  0.782313  1.094571  1.136015  1.349879  0.008700
# 2021-12-31  0.724980  0.784658  1.094451  1.132503  1.349837  0.008691
#
# [3388 rows x 6 columns]

# %%
fx.plot(figsize=(12,8), fontsize=13)
plt.legend(fontsize=13, loc=1, bbox_to_anchor=(0.6, 0.4, 0.6, 0.6))
plt.show()

# %%
fx.drop(columns='JPYUSD=X').plot(figsize=(12,8), fontsize=13)
plt.legend(fontsize=13, loc=1, bbox_to_anchor=(0.6, 0.4, 0.6, 0.6))
plt.show()

# %%
fig, axs = plt.subplots(3,2, figsize=(16,10), gridspec_kw={'hspace': 0.2, 'wspace': 0.1})
axs[0,0].plot(fx['AUDUSD=X'])
axs[0,0].set_title('AUD')
axs[0,1].plot(fx['CADUSD=X'])
axs[0,1].set_title('CAD')
axs[1,0].plot(fx['CHFUSD=X'])
axs[1,0].set_title('CHF')
axs[1,1].plot(fx['EURUSD=X'])
axs[1,1].set_title('EUR')
axs[2,0].plot(fx['GBPUSD=X'])
axs[2,0].set_title('GBP')
axs[2,1].plot(fx['JPYUSD=X'])
axs[2,1].set_title('JPY');

# %%
fx = fx.loc['2018':]
fx
# Out:
#             AUDUSD=X  CADUSD=X  CHFUSD=X  EURUSD=X  GBPUSD=X  JPYUSD=X
# Date
# 2018-01-01  0.780214  0.794862  1.026979  1.200495  1.351607  0.008876
# 2018-01-02  0.780104  0.796495  1.025936  1.201158  1.351132  0.008868
# 2018-01-03  0.783392  0.799750  1.029379  1.206345  1.359619  0.008909
# 2018-01-04  0.782840  0.797010  1.023395  1.201043  1.351132  0.008880
# 2018-01-05  0.786380  0.800621  1.026273  1.206884  1.355289  0.008867
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-27  0.723129  0.780396  1.088399  1.132426  1.340430  0.008746
# 2021-12-28  0.723700  0.782044  1.090322  1.133003  1.344267  0.008711
# 2021-12-29  0.723400  0.780457  1.090631  1.131478  1.343328  0.008713
# 2021-12-30  0.725879  0.782313  1.094571  1.136015  1.349879  0.008700
# 2021-12-31  0.724980  0.784658  1.094451  1.132503  1.349837  0.008691
#
# [1044 rows x 6 columns]

# %%
start = '2009-07-14'
end = '2022-01-01'
cryp = yf.download(tickers=cryp_tickers, start=start, end=end)['Adj Close']
cryp
# Out:
# [*********************100%***********************]  11 of 11 completed
#              ADA-USD     BCH-USD     BNB-USD       BTC-USD  DOGE-USD  \
# Date
# 2014-09-17       NaN         NaN         NaN    457.334015       NaN
# 2014-09-18       NaN         NaN         NaN    424.440002       NaN
# 2014-09-19       NaN         NaN         NaN    394.795990       NaN
# 2014-09-20       NaN         NaN         NaN    408.903992       NaN
# 2014-09-21       NaN         NaN         NaN    398.821014       NaN
# ...              ...         ...         ...           ...       ...
# 2021-12-28  1.402264  439.571533  534.928040  47588.855469  0.174117
# 2021-12-29  1.330814  430.083099  514.000793  46444.710938  0.167765
# 2021-12-30  1.360415  431.536743  518.909729  47178.125000  0.171313
# 2021-12-31  1.310209  430.639557  511.708313  46306.445312  0.170496
# 2022-01-01  1.376975  444.456177  527.352722  47686.812500  0.173035
#
# ...

# %%
cryp['BTC-USD'].plot(figsize=(12,8))
plt.legend(fontsize=13)
plt.show()

# %%
fig, axs = plt.subplots(4,2, figsize=(16,16), gridspec_kw ={'hspace': 0.2, 'wspace': 0.1})
axs[0,0].plot(cryp['BNB-USD'])
axs[0,0].set_title('BNB')
axs[0,1].plot(cryp['BTC-USD'])
axs[0,1].set_title('BTC')
axs[1,0].plot(cryp['ETH-USD'])
axs[1,0].set_title('ETH')
axs[1,1].plot(cryp['XRP-USD'])
axs[1,1].set_title('XRP')
axs[2,0].plot(cryp['USDT-USD'])
axs[2,0].set_title('USDT')
axs[2,1].plot(cryp['ADA-USD'])
axs[2,1].set_title('ADA')
axs[3,0].plot(cryp['DOGE-USD'])
axs[3,0].set_title('DOGE')
axs[3,1].plot(cryp['LTC-USD'])
axs[3,1].set_title('LTC');

# %%
cryp = cryp.loc['2018':]
cryp
# Out:
#              ADA-USD      BCH-USD     BNB-USD       BTC-USD  DOGE-USD  \
# Date
# 2018-01-01  0.728657  2432.540039    8.414610  13657.200195  0.008909
# 2018-01-02  0.782587  2711.000000    8.837770  14982.099609  0.009145
# 2018-01-03  1.079660  2608.689941    9.535880  15201.000000  0.009320
# 2018-01-04  1.114120  2430.179932    9.213990  15599.200195  0.009644
# 2018-01-05  0.999559  2584.479980   14.917200  17429.500000  0.012167
# ...              ...          ...         ...           ...       ...
# 2021-12-28  1.402264   439.571533  534.928040  47588.855469  0.174117
# 2021-12-29  1.330814   430.083099  514.000793  46444.710938  0.167765
# 2021-12-30  1.360415   431.536743  518.909729  47178.125000  0.171313
# 2021-12-31  1.310209   430.639557  511.708313  46306.445312  0.170496
# 2022-01-01  1.376975   444.456177  527.352722  47686.812500  0.173035
#
#                 ETH-USD     LTC-USD  USDT-USD   XLM-USD     XMR-USD   XRP-USD
# Date
# ...

# %%
cryp.plot(figsize=(12,8), fontsize=12)
plt.show()

# %%
cryp.drop(columns=['BTC-USD', 'ETH-USD']).plot(figsize=(12,8), fontsize=12)
plt.show()

# %% [markdown]
# ### Data Normalization

# %%
data = pd.concat([fx, cryp], axis=1)
data
# Out:
#             AUDUSD=X  CADUSD=X  CHFUSD=X  EURUSD=X  GBPUSD=X  JPYUSD=X  \
# Date
# 2018-01-01  0.780214  0.794862  1.026979  1.200495  1.351607  0.008876
# 2018-01-02  0.780104  0.796495  1.025936  1.201158  1.351132  0.008868
# 2018-01-03  0.783392  0.799750  1.029379  1.206345  1.359619  0.008909
# 2018-01-04  0.782840  0.797010  1.023395  1.201043  1.351132  0.008880
# 2018-01-05  0.786380  0.800621  1.026273  1.206884  1.355289  0.008867
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-28  0.723700  0.782044  1.090322  1.133003  1.344267  0.008711
# 2021-12-29  0.723400  0.780457  1.090631  1.131478  1.343328  0.008713
# 2021-12-30  0.725879  0.782313  1.094571  1.136015  1.349879  0.008700
# 2021-12-31  0.724980  0.784658  1.094451  1.132503  1.349837  0.008691
# 2022-01-01       NaN       NaN       NaN       NaN       NaN       NaN
#
#              ADA-USD      BCH-USD     BNB-USD       BTC-USD  DOGE-USD  \
# Date
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1462 entries, 2018-01-01 to 2022-01-01
# Freq: D
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   AUDUSD=X  1044 non-null   float64
#  1   CADUSD=X  1044 non-null   float64
#  2   CHFUSD=X  1044 non-null   float64
#  3   EURUSD=X  1044 non-null   float64
#  4   GBPUSD=X  1044 non-null   float64
#  5   JPYUSD=X  1044 non-null   float64
#  6   ADA-USD   1462 non-null   float64
#  7   BCH-USD   1462 non-null   float64
#  8   BNB-USD   1462 non-null   float64
#  9   BTC-USD   1462 non-null   float64
#  10  DOGE-USD  1462 non-null   float64
#  11  ETH-USD   1462 non-null   float64
#  12  LTC-USD   1462 non-null   float64
#  13  USDT-USD  1462 non-null   float64
#  14  XLM-USD   1462 non-null   float64
#  15  XMR-USD   1462 non-null   float64
#  16  XRP-USD   1462 non-null   float64
# dtypes: float64(17)
# memory usage: 205.6 KB

# %%
df = data.div(data.iloc[0]).mul(100)
df
# Out:
#               AUDUSD=X    CADUSD=X    CHFUSD=X    EURUSD=X    GBPUSD=X  \
# Date
# 2018-01-01  100.000000  100.000000  100.000000  100.000000  100.000000
# 2018-01-02   99.985959  100.205495   99.898432  100.055251   99.964871
# 2018-01-03  100.407363  100.615002  100.233676  100.487365  100.592798
# 2018-01-04  100.336620  100.270180   99.651024  100.045638   99.964871
# 2018-01-05  100.790317  100.724558   99.931247  100.532229  100.272409
# ...                ...         ...         ...         ...         ...
# 2021-12-28   92.756628   98.387426  106.167961   94.378033   99.456911
# 2021-12-29   92.718178   98.187779  106.198060   94.250959   99.387446
# 2021-12-30   93.035914   98.421290  106.581650   94.628915   99.872166
# 2021-12-31   92.920710   98.716291  106.569996   94.336347   99.869061
# 2022-01-01         NaN         NaN         NaN         NaN         NaN
#
#               JPYUSD=X     ADA-USD     BCH-USD      BNB-USD     BTC-USD  \
# Date
# ...

# %%
df.plot(figsize=(12,8), fontsize=13, logy=True)
plt.legend(fontsize=13, loc=1, bbox_to_anchor=(0.6, 0.4, 0.6, 0.6))
plt.show()

# %%
log_returns = np.log(df.div(df.shift()))    # log returns
log_returns
# Out:
#             AUDUSD=X  CADUSD=X  CHFUSD=X  EURUSD=X  GBPUSD=X  JPYUSD=X  \
# Date
# 2018-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-02 -0.000140  0.002053 -0.001016  0.000552 -0.000351 -0.000923
# 2018-01-03  0.004206  0.004078  0.003350  0.004309  0.006262  0.004675
# 2018-01-04 -0.000705 -0.003433 -0.005830 -0.004406 -0.006262 -0.003229
# 2018-01-05  0.004512  0.004521  0.002808  0.004852  0.003072 -0.001562
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-28  0.000790  0.002109  0.001766  0.000510  0.002858 -0.004006
# 2021-12-29 -0.000415 -0.002031  0.000283 -0.001347 -0.000699  0.000165
# 2021-12-30  0.003421  0.002375  0.003606  0.004002  0.004865 -0.001524
# 2021-12-31 -0.001239  0.002993 -0.000109 -0.003097 -0.000031 -0.001000
# 2022-01-01       NaN       NaN       NaN       NaN       NaN       NaN
#
#              ADA-USD   BCH-USD   BNB-USD   BTC-USD  DOGE-USD   ETH-USD  \
# Date
# ...

# %%
log_returns.to_csv('log_returns.csv')

# %%
log_returns = pd.read_csv('log_returns.csv', index_col='Date', parse_dates=['Date'])
log_returns
# Out:
#             AUDUSD=X  CADUSD=X  CHFUSD=X  EURUSD=X  GBPUSD=X  JPYUSD=X  \
# Date
# 2018-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-02 -0.000140  0.002053 -0.001016  0.000552 -0.000351 -0.000923
# 2018-01-03  0.004206  0.004078  0.003350  0.004309  0.006262  0.004675
# 2018-01-04 -0.000705 -0.003433 -0.005830 -0.004406 -0.006262 -0.003229
# 2018-01-05  0.004512  0.004521  0.002808  0.004852  0.003072 -0.001562
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-28  0.000790  0.002109  0.001766  0.000510  0.002858 -0.004006
# 2021-12-29 -0.000415 -0.002031  0.000283 -0.001347 -0.000699  0.000165
# 2021-12-30  0.003421  0.002375  0.003606  0.004002  0.004865 -0.001524
# 2021-12-31 -0.001239  0.002993 -0.000109 -0.003097 -0.000031 -0.001000
# 2022-01-01       NaN       NaN       NaN       NaN       NaN       NaN
#
#              ADA-USD   BCH-USD   BNB-USD   BTC-USD  DOGE-USD   ETH-USD  \
# Date
# ...

# %%
log_returns.describe()
# Out:
#          AUDUSD=X    CADUSD=X    CHFUSD=X    EURUSD=X    GBPUSD=X    JPYUSD=X  \
# count  834.000000  834.000000  834.000000  834.000000  834.000000  834.000000
# mean    -0.000077    0.000006   -0.000069   -0.000082    0.000059   -0.000141
# std      0.005954    0.004392    0.004058    0.003991    0.005409    0.004062
# min     -0.032195   -0.017107   -0.022595   -0.028144   -0.041806   -0.026689
# 25%     -0.003395   -0.002476   -0.002385   -0.002441   -0.002860   -0.002454
# 50%     -0.000062   -0.000071   -0.000144    0.000000   -0.000041   -0.000267
# 75%      0.003217    0.002310    0.002355    0.002379    0.003105    0.002049
# max      0.028533    0.031938    0.015047    0.014467    0.029062    0.020516
#
#            ADA-USD      BCH-USD      BNB-USD      BTC-USD     DOGE-USD  \
# count  1461.000000  1461.000000  1461.000000  1461.000000  1461.000000
# mean      0.000436    -0.001163     0.002832     0.000856     0.002030
# ...

# %%
mu = log_returns.mean()    # mean of log returns
mu
# Out:
# AUDUSD=X   -0.000077
# CADUSD=X    0.000006
# CHFUSD=X   -0.000069
# EURUSD=X   -0.000082
# GBPUSD=X    0.000059
# JPYUSD=X   -0.000141
# ADA-USD     0.000436
# BCH-USD    -0.001163
# BNB-USD     0.002832
# BTC-USD     0.000856
# DOGE-USD    0.002030
# ETH-USD     0.001085
# LTC-USD    -0.000287
# USDT-USD   -0.000005
# XLM-USD    -0.000378
# XMR-USD    -0.000247
# XRP-USD    -0.000708
# dtype: float64

# %%
sigma = log_returns.std()    # std of log returns
sigma
# Out:
# AUDUSD=X    0.005954
# CADUSD=X    0.004392
# CHFUSD=X    0.004058
# EURUSD=X    0.003991
# GBPUSD=X    0.005409
# JPYUSD=X    0.004062
# ADA-USD     0.061277
# BCH-USD     0.064036
# BNB-USD     0.060718
# BTC-USD     0.040240
# DOGE-USD    0.081415
# ETH-USD     0.052071
# LTC-USD     0.054936
# USDT-USD    0.004390
# XLM-USD     0.061321
# XMR-USD     0.055050
# XRP-USD     0.062611
# dtype: float64

# %% [markdown]
# ### Volatility

# %%
fig, axs = plt.subplots(3,2, figsize=(16,10), gridspec_kw ={'hspace': 0.2, 'wspace': 0.1})
axs[0,0].plot(log_returns['AUDUSD=X'])
axs[0,0].set_title('AUD')
axs[0,1].plot(log_returns['CADUSD=X'])
axs[0,1].set_title('CAD')
axs[1,0].plot(log_returns['CHFUSD=X'])
axs[1,0].set_title('CHF')
axs[1,1].plot(log_returns['EURUSD=X'])
axs[1,1].set_title('EUR')
axs[2,0].plot(log_returns['GBPUSD=X'])
axs[2,0].set_title('GBP')
axs[2,1].plot(log_returns['JPYUSD=X'])
axs[2,1].set_title('JPY');

# %%
fig, axs = plt.subplots(4,2, figsize=(16,16), gridspec_kw ={'hspace': 0.2, 'wspace': 0.1})
axs[0,0].plot(log_returns['BNB-USD'])
axs[0,0].set_title('BNB')
axs[0,1].plot(log_returns['BTC-USD'])
axs[0,1].set_title('BTC')
axs[1,0].plot(log_returns['ETH-USD'])
axs[1,0].set_title('ETH')
axs[1,1].plot(log_returns['XRP-USD'])
axs[1,1].set_title('XRP')
axs[2,0].plot(log_returns['USDT-USD'])
axs[2,0].set_title('USDT')
axs[2,1].plot(log_returns['ADA-USD'])
axs[2,1].set_title('ADA')
axs[3,0].plot(log_returns['DOGE-USD'])
axs[3,0].set_title('DOGE')
axs[3,1].plot(log_returns['LTC-USD'])
axs[3,1].set_title('LTC');

# %%
log_returns.min()
# Out:
# AUDUSD=X   -0.032195
# CADUSD=X   -0.017107
# CHFUSD=X   -0.022595
# EURUSD=X   -0.028144
# GBPUSD=X   -0.041806
# JPYUSD=X   -0.026689
# ADA-USD    -0.503638
# BCH-USD    -0.561348
# BNB-USD    -0.543084
# BTC-USD    -0.464730
# DOGE-USD   -0.515118
# ETH-USD    -0.550732
# LTC-USD    -0.449062
# USDT-USD   -0.052570
# XLM-USD    -0.409950
# XMR-USD    -0.534196
# XRP-USD    -0.550503
# dtype: float64

# %%
log_returns.max()
# Out:
# AUDUSD=X    0.028533
# CADUSD=X    0.031938
# CHFUSD=X    0.015047
# EURUSD=X    0.014467
# GBPUSD=X    0.029062
# JPYUSD=X    0.020516
# ADA-USD     0.321796
# BCH-USD     0.420814
# BNB-USD     0.529218
# BTC-USD     0.171821
# DOGE-USD    1.516328
# ETH-USD     0.230695
# LTC-USD     0.290594
# USDT-USD    0.053393
# XLM-USD     0.559184
# XMR-USD     0.344954
# XRP-USD     0.444756
# dtype: float64

# %% [markdown]
# ### Histogram

# %%
fig, axs = plt.subplots(3,2, figsize=(16,10), gridspec_kw ={'hspace': 0.2, 'wspace': 0.1})
axs[0,0].hist(log_returns['AUDUSD=X'], bins=50, range=(-0.04, 0.04))
axs[0,0].set_title('AUD')
axs[0,1].hist(log_returns['CADUSD=X'], bins=50, range=(-0.04, 0.04))
axs[0,1].set_title('CAD')
axs[1,0].hist(log_returns['CHFUSD=X'], bins=50, range=(-0.04, 0.04))
axs[1,0].set_title('CHF')
axs[1,1].hist(log_returns['EURUSD=X'], bins=50, range=(-0.04, 0.04))
axs[1,1].set_title('EUR')
axs[2,0].hist(log_returns['GBPUSD=X'], bins=50, range=(-0.04, 0.04))
axs[2,0].set_title('GBP')
axs[2,1].hist(log_returns['JPYUSD=X'], bins=50, range=(-0.04, 0.04))
axs[2,1].set_title('JPY');

# %%
fig, axs = plt.subplots(4,2, figsize=(16,16), gridspec_kw={'hspace': 0.2, 'wspace': 0.1})
axs[0,0].hist(log_returns['BNB-USD'], bins=50, range=(-0.5, 0.5))
axs[0,0].set_title('BNB')
axs[0,1].hist(log_returns['BTC-USD'], bins=50, range=(-0.5, 0.5))
axs[0,1].set_title('BTC')
axs[1,0].hist(log_returns['ETH-USD'], bins=50, range=(-0.5, 0.5))
axs[1,0].set_title('ETH')
axs[1,1].hist(log_returns['XRP-USD'], bins=50, range=(-0.5, 0.5))
axs[1,1].set_title('XRP')
axs[2,0].hist(log_returns['USDT-USD'], bins=50, range=(-0.5, 0.5))
axs[2,0].set_title('USDT')
axs[2,1].hist(log_returns['ADA-USD'], bins=50, range=(-0.5, 0.5))
axs[2,1].set_title('ADA')
axs[3,0].hist(log_returns['DOGE-USD'], bins=50, range=(-0.5, 0.5))
axs[3,0].set_title('DOGE')
axs[3,1].hist(log_returns['LTC-USD'], bins=50, range=(-0.5, 0.5))
axs[3,1].set_title('LTC');

# %%
corr = log_returns.corr()
corr
# Out:
#           AUDUSD=X  CADUSD=X  CHFUSD=X  EURUSD=X  GBPUSD=X  JPYUSD=X  \
# AUDUSD=X  1.000000  0.659122  0.391324  0.584679  0.592416  0.149515
# CADUSD=X  0.659122  1.000000  0.274588  0.442934  0.486961  0.074537
# CHFUSD=X  0.391324  0.274588  1.000000  0.774323  0.451439  0.540260
# EURUSD=X  0.584679  0.442934  0.774323  1.000000  0.581239  0.387653
# GBPUSD=X  0.592416  0.486961  0.451439  0.581239  1.000000  0.226506
# JPYUSD=X  0.149515  0.074537  0.540260  0.387653  0.226506  1.000000
# ADA-USD  -0.084411 -0.037200 -0.050146 -0.026177 -0.060971 -0.063061
# BCH-USD  -0.097346 -0.043382 -0.057269 -0.039496 -0.045992 -0.033600
# BNB-USD  -0.057843 -0.039919 -0.009010 -0.017868 -0.049718 -0.003271
# BTC-USD  -0.109004 -0.043637 -0.027632 -0.039470 -0.093338 -0.034507
# DOGE-USD -0.080969 -0.049501 -0.045232 -0.059178 -0.050008 -0.049328
# ETH-USD  -0.074821 -0.041378 -0.009995 -0.019803 -0.071897 -0.020709
# LTC-USD  -0.071110 -0.037901 -0.024051 -0.016767 -0.043738 -0.024292
# ...

# %%
min_corr = corr.min()
min_corr.sort_values(ascending=False)
# Out:
# XLM-USD    -0.048134
# CHFUSD=X   -0.057269
# BNB-USD    -0.057843
# EURUSD=X   -0.059178
# XRP-USD    -0.060225
# JPYUSD=X   -0.063061
# CADUSD=X   -0.067654
# USDT-USD   -0.069339
# LTC-USD    -0.071110
# ETH-USD    -0.074821
# DOGE-USD   -0.080969
# ADA-USD    -0.084411
# XMR-USD    -0.087051
# GBPUSD=X   -0.093338
# BCH-USD    -0.097346
# BTC-USD    -0.109004
# AUDUSD=X   -0.109004
# dtype: float64

# %%
np.min(min_corr)
# Out:
# -0.10900397503181465

# %%
new_corr = corr - np.identity(len(tickers))
corr_max = new_corr.max().sort_values(ascending=False)
corr_max
# Out:
# ETH-USD     0.833291
# LTC-USD     0.833291
# BCH-USD     0.824483
# BTC-USD     0.819733
# CHFUSD=X    0.774323
# EURUSD=X    0.774323
# XLM-USD     0.772489
# ADA-USD     0.772489
# XMR-USD     0.766900
# XRP-USD     0.741194
# BNB-USD     0.671282
# CADUSD=X    0.659122
# AUDUSD=X    0.659122
# GBPUSD=X    0.592416
# JPYUSD=X    0.540260
# DOGE-USD    0.480280
# USDT-USD    0.080645
# dtype: float64

# %%
for i in corr_max.index: 
    print(f'Correlation between {i} and {new_corr[i].idxmax()} is {new_corr[i].max():.2f}')
# Out:
# Correlation between ETH-USD and LTC-USD is 0.83
# Correlation between LTC-USD and ETH-USD is 0.83
# Correlation between BCH-USD and LTC-USD is 0.82
# Correlation between BTC-USD and ETH-USD is 0.82
# Correlation between CHFUSD=X and EURUSD=X is 0.77
# Correlation between EURUSD=X and CHFUSD=X is 0.77
# Correlation between XLM-USD and ADA-USD is 0.77
# Correlation between ADA-USD and XLM-USD is 0.77
# Correlation between XMR-USD and BTC-USD is 0.77
# Correlation between XRP-USD and XLM-USD is 0.74
# Correlation between BNB-USD and ETH-USD is 0.67
# Correlation between CADUSD=X and AUDUSD=X is 0.66
# Correlation between AUDUSD=X and CADUSD=X is 0.66
# Correlation between GBPUSD=X and AUDUSD=X is 0.59
# Correlation between JPYUSD=X and CHFUSD=X is 0.54
# Correlation between DOGE-USD and LTC-USD is 0.48
# Correlation between USDT-USD and AUDUSD=X is 0.08

# %%
plt.figure(figsize=(20,12))
sns.heatmap(corr, cmap='RdYlGn', annot=True, vmin=-0.2, vmax=0.7)
plt.yticks(rotation=0)
plt.title('Correlation - FX & Crypto', fontdict={'fontweight': 'bold', 'fontsize': 18})
plt.show()

# %% [markdown]
# ### Annualized Return and Standard Deviation

# %%
td_year = log_returns.count() / ((log_returns.index[-1] - log_returns.index[0]).days / 365.25)  # trading days per year
td_year
# Out:
# AUDUSD=X    208.50
# CADUSD=X    208.50
# CHFUSD=X    208.50
# EURUSD=X    208.50
# GBPUSD=X    208.50
# JPYUSD=X    208.50
# ADA-USD     365.25
# BCH-USD     365.25
# BNB-USD     365.25
# BTC-USD     365.25
# DOGE-USD    365.25
# ETH-USD     365.25
# LTC-USD     365.25
# USDT-USD    365.25
# XLM-USD     365.25
# XMR-USD     365.25
# XRP-USD     365.25
# dtype: float64

# %%
ann_ret = mu * td_year
ann_ret
# Out:
# AUDUSD=X   -0.015955
# CADUSD=X    0.001197
# CHFUSD=X   -0.014304
# EURUSD=X   -0.017131
# GBPUSD=X    0.012276
# JPYUSD=X   -0.029398
# ADA-USD     0.159110
# BCH-USD    -0.424960
# BNB-USD     1.034475
# BTC-USD     0.312597
# DOGE-USD    0.741608
# ETH-USD     0.396234
# LTC-USD    -0.104648
# USDT-USD   -0.001688
# XLM-USD    -0.138047
# XMR-USD    -0.090252
# XRP-USD    -0.258716
# dtype: float64

# %%
np.exp(ann_ret) - 1       # CAGR (Compound Annual Growth Rate)
# Out:
# AUDUSD=X   -0.015828
# CADUSD=X    0.001198
# CHFUSD=X   -0.014202
# EURUSD=X   -0.016985
# GBPUSD=X    0.012351
# JPYUSD=X   -0.028970
# ADA-USD     0.172467
# BCH-USD    -0.346204
# BNB-USD     1.813629
# BTC-USD     0.366971
# DOGE-USD    1.099308
# ETH-USD     0.486217
# LTC-USD    -0.099359
# USDT-USD   -0.001687
# XLM-USD    -0.128942
# XMR-USD    -0.086299
# XRP-USD    -0.227958
# dtype: float64

# %%
ann_std = sigma * np.sqrt(td_year)
ann_std
# Out:
# AUDUSD=X    0.085977
# CADUSD=X    0.063424
# CHFUSD=X    0.058599
# EURUSD=X    0.057622
# GBPUSD=X    0.078104
# JPYUSD=X    0.058660
# ADA-USD     1.171091
# BCH-USD     1.223833
# BNB-USD     1.160420
# BTC-USD     0.769040
# DOGE-USD    1.555965
# ETH-USD     0.995160
# LTC-USD     1.049906
# USDT-USD    0.083906
# XLM-USD     1.171941
# XMR-USD     1.052087
# XRP-USD     1.196589
# dtype: float64

# %%
output = pd.DataFrame(data={'Ann_Return': ann_ret, 'Ann_Risk': ann_std})
output
# Out:
#           Ann_Return  Ann_Risk
# AUDUSD=X   -0.015955  0.085977
# CADUSD=X    0.001197  0.063424
# CHFUSD=X   -0.014304  0.058599
# EURUSD=X   -0.017131  0.057622
# GBPUSD=X    0.012276  0.078104
# JPYUSD=X   -0.029398  0.058660
# ADA-USD     0.159110  1.171091
# BCH-USD    -0.424960  1.223833
# BNB-USD     1.034475  1.160420
# BTC-USD     0.312597  0.769040
# DOGE-USD    0.741608  1.555965
# ETH-USD     0.396234  0.995160
# LTC-USD    -0.104648  1.049906
# USDT-USD   -0.001688  0.083906
# XLM-USD    -0.138047  1.171941
# XMR-USD    -0.090252  1.052087
# XRP-USD    -0.258716  1.196589

# %%
output.rank(ascending=False).sort_values('Ann_Return')
# Out:
#           Ann_Return  Ann_Risk
# BNB-USD          1.0       6.0
# DOGE-USD         2.0       1.0
# ETH-USD          3.0       9.0
# BTC-USD          4.0      10.0
# ADA-USD          5.0       5.0
# GBPUSD=X         6.0      13.0
# CADUSD=X         7.0      14.0
# USDT-USD         8.0      12.0
# CHFUSD=X         9.0      16.0
# AUDUSD=X        10.0      11.0
# EURUSD=X        11.0      17.0
# JPYUSD=X        12.0      15.0
# XMR-USD         13.0       7.0
# LTC-USD         14.0       8.0
# XLM-USD         15.0       4.0
# XRP-USD         16.0       3.0
# BCH-USD         17.0       2.0

# %% [markdown]
# ## Sharpe Ratio

# %%
output
# Out:
#           Ann_Return  Ann_Risk
# AUDUSD=X   -0.015955  0.085977
# CADUSD=X    0.001197  0.063424
# CHFUSD=X   -0.014304  0.058599
# EURUSD=X   -0.017131  0.057622
# GBPUSD=X    0.012276  0.078104
# JPYUSD=X   -0.029398  0.058660
# ADA-USD     0.159110  1.171091
# BCH-USD    -0.424960  1.223833
# BNB-USD     1.034475  1.160420
# BTC-USD     0.312597  0.769040
# DOGE-USD    0.741608  1.555965
# ETH-USD     0.396234  0.995160
# LTC-USD    -0.104648  1.049906
# USDT-USD   -0.001688  0.083906
# XLM-USD    -0.138047  1.171941
# XMR-USD    -0.090252  1.052087
# XRP-USD    -0.258716  1.196589

# %%
x_min = output['Ann_Risk'].min()
x_min
# Out:
# 0.05762244714924771

# %%
x_max = output['Ann_Risk'].max()
x_max
# Out:
# 1.5559648179720753

# %%
y_min = output['Ann_Return'].min()
y_min
# Out:
# -0.42495995346211646

# %%
y_max = output['Ann_Return'].max()
y_max
# Out:
# 1.0344750391837767

# %%
cryp
# Out:
#              ADA-USD      BCH-USD     BNB-USD       BTC-USD  DOGE-USD  \
# Date
# 2018-01-01  0.728657  2432.540039    8.414610  13657.200195  0.008909
# 2018-01-02  0.782587  2711.000000    8.837770  14982.099609  0.009145
# 2018-01-03  1.079660  2608.689941    9.535880  15201.000000  0.009320
# 2018-01-04  1.114120  2430.179932    9.213990  15599.200195  0.009644
# 2018-01-05  0.999559  2584.479980   14.917200  17429.500000  0.012167
# ...              ...          ...         ...           ...       ...
# 2021-12-28  1.402264   439.571533  534.928040  47588.855469  0.174117
# 2021-12-29  1.330814   430.083099  514.000793  46444.710938  0.167765
# 2021-12-30  1.360415   431.536743  518.909729  47178.125000  0.171313
# 2021-12-31  1.310209   430.639557  511.708313  46306.445312  0.170496
# 2022-01-01  1.376975   444.456177  527.352722  47686.812500  0.173035
#
#                 ETH-USD     LTC-USD  USDT-USD   XLM-USD     XMR-USD   XRP-USD
# Date
# ...

# %%
cryp.columns
# Out:
# Index(['ADA-USD', 'BCH-USD', 'BNB-USD', 'BTC-USD', 'DOGE-USD', 'ETH-USD',
#        'LTC-USD', 'USDT-USD', 'XLM-USD', 'XMR-USD', 'XRP-USD'],
#       dtype='object')

# %%
output
# Out:
#           Ann_Return  Ann_Risk
# AUDUSD=X   -0.015955  0.085977
# CADUSD=X    0.001197  0.063424
# CHFUSD=X   -0.014304  0.058599
# EURUSD=X   -0.017131  0.057622
# GBPUSD=X    0.012276  0.078104
# JPYUSD=X   -0.029398  0.058660
# ADA-USD     0.159110  1.171091
# BCH-USD    -0.424960  1.223833
# BNB-USD     1.034475  1.160420
# BTC-USD     0.312597  0.769040
# DOGE-USD    0.741608  1.555965
# ETH-USD     0.396234  0.995160
# LTC-USD    -0.104648  1.049906
# USDT-USD   -0.001688  0.083906
# XLM-USD    -0.138047  1.171941
# XMR-USD    -0.090252  1.052087
# XRP-USD    -0.258716  1.196589

# %%
output.plot(kind='scatter', x='Ann_Risk', y='Ann_Return', figsize=(15,10), s=25, fontsize=13)
for i in cryp.drop(columns='LTC-USD').columns:     
    plt.annotate(i.replace('-USD',''), xy=(output.loc[i,'Ann_Risk']+0.01, output.loc[i,'Ann_Return']+0.01), size=13)
plt.annotate('LTC', xy=(output.loc['LTC-USD','Ann_Risk']+0.01, output.loc['LTC-USD','Ann_Return']-0.015), size=13)                 
plt.xlim(x_min-0.05, x_max+0.05)   
plt.ylim(y_min-0.05, y_max+0.05) 
plt.xlabel('Risk (std)', fontsize=15)     
plt.ylabel('Return', fontsize=15)
plt.title('Risk/Return', fontdict={'fontweight': 'bold', 'fontsize': 18})
plt.show()

# %%
r_f = 0       #  risk free rate (simplification)

# %%
def sharpe(log_ret, r_f=0):
    
    if log_ret.std() == 0:
        return np.nan
    else:
        return(log_ret.mean() - r_f) / log_ret.std() * np.sqrt(log_ret.count() / ((log_ret.index[-1] - log_ret.index[0]).days / 365.25))

# %%
log_returns.apply(sharpe).sort_values(ascending=False)
# Out:
# BNB-USD     0.891466
# DOGE-USD    0.476623
# BTC-USD     0.406477
# ETH-USD     0.398161
# GBPUSD=X    0.157171
# ADA-USD     0.135865
# CADUSD=X    0.018875
# USDT-USD   -0.020123
# XMR-USD    -0.085784
# LTC-USD    -0.099674
# XLM-USD    -0.117794
# AUDUSD=X   -0.185567
# XRP-USD    -0.216211
# CHFUSD=X   -0.244093
# EURUSD=X   -0.297298
# BCH-USD    -0.347237
# JPYUSD=X   -0.501151
# dtype: float64

# %%
output['Sharpe'] = log_returns.apply(sharpe)
output
# Out:
#           Ann_Return  Ann_Risk    Sharpe
# AUDUSD=X   -0.015955  0.085977 -0.185567
# CADUSD=X    0.001197  0.063424  0.018875
# CHFUSD=X   -0.014304  0.058599 -0.244093
# EURUSD=X   -0.017131  0.057622 -0.297298
# GBPUSD=X    0.012276  0.078104  0.157171
# JPYUSD=X   -0.029398  0.058660 -0.501151
# ADA-USD     0.159110  1.171091  0.135865
# BCH-USD    -0.424960  1.223833 -0.347237
# BNB-USD     1.034475  1.160420  0.891466
# BTC-USD     0.312597  0.769040  0.406477
# DOGE-USD    0.741608  1.555965  0.476623
# ETH-USD     0.396234  0.995160  0.398161
# LTC-USD    -0.104648  1.049906 -0.099674
# USDT-USD   -0.001688  0.083906 -0.020123
# XLM-USD    -0.138047  1.171941 -0.117794
# XMR-USD    -0.090252  1.052087 -0.085784
# XRP-USD    -0.258716  1.196589 -0.216211

# %% [markdown]
# ## Sortino Ratio

# %%
def sortino(log_ret, r_f=0):       
    excess_returns = log_ret - r_f
    excess_returns = np.where(excess_returns<0, excess_returns, 0)
    downside_deviation = np.sqrt(np.mean(excess_returns ** 2))
    if downside_deviation == 0:
        return np.nan
    else:
        return ((log_ret.mean() - r_f) / downside_deviation) * np.sqrt(log_ret.count() / ((log_ret.index[-1] - log_ret.index[0]).days / 365.25))

# %%
log_returns.apply(sortino).sort_values(ascending=False)
# Out:
# BNB-USD     1.329195
# DOGE-USD    0.867731
# BTC-USD     0.554517
# ETH-USD     0.538976
# GBPUSD=X    0.293302
# ADA-USD     0.195862
# CADUSD=X    0.036524
# USDT-USD   -0.028920
# XMR-USD    -0.112833
# LTC-USD    -0.136243
# XLM-USD    -0.172423
# XRP-USD    -0.306262
# AUDUSD=X   -0.341570
# CHFUSD=X   -0.442057
# BCH-USD    -0.477453
# EURUSD=X   -0.530800
# JPYUSD=X   -0.906074
# dtype: float64

# %%
output ['Sortino'] = log_returns.apply(sortino)
output
# Out:
#           Ann_Return  Ann_Risk    Sharpe   Sortino
# AUDUSD=X   -0.015955  0.085977 -0.185567 -0.341570
# CADUSD=X    0.001197  0.063424  0.018875  0.036524
# CHFUSD=X   -0.014304  0.058599 -0.244093 -0.442057
# EURUSD=X   -0.017131  0.057622 -0.297298 -0.530800
# GBPUSD=X    0.012276  0.078104  0.157171  0.293302
# JPYUSD=X   -0.029398  0.058660 -0.501151 -0.906074
# ADA-USD     0.159110  1.171091  0.135865  0.195862
# BCH-USD    -0.424960  1.223833 -0.347237 -0.477453
# BNB-USD     1.034475  1.160420  0.891466  1.329195
# BTC-USD     0.312597  0.769040  0.406477  0.554517
# DOGE-USD    0.741608  1.555965  0.476623  0.867731
# ETH-USD     0.396234  0.995160  0.398161  0.538976
# LTC-USD    -0.104648  1.049906 -0.099674 -0.136243
# USDT-USD   -0.001688  0.083906 -0.020123 -0.028920
# XLM-USD    -0.138047  1.171941 -0.117794 -0.172423
# XMR-USD    -0.090252  1.052087 -0.085784 -0.112833
# XRP-USD    -0.258716  1.196589 -0.216211 -0.306262

# %% [markdown]
# ## Calmar Ratio

# %%
df
# Out:
#               AUDUSD=X    CADUSD=X    CHFUSD=X    EURUSD=X    GBPUSD=X  \
# Date
# 2018-01-01  100.000000  100.000000  100.000000  100.000000  100.000000
# 2018-01-02   99.985959  100.205495   99.898432  100.055251   99.964871
# 2018-01-03  100.407363  100.615002  100.233676  100.487365  100.592798
# 2018-01-04  100.336620  100.270180   99.651024  100.045638   99.964871
# 2018-01-05  100.790317  100.724558   99.931247  100.532229  100.272409
# ...                ...         ...         ...         ...         ...
# 2021-12-28   92.756628   98.387426  106.167961   94.378033   99.456911
# 2021-12-29   92.718178   98.187779  106.198060   94.250959   99.387446
# 2021-12-30   93.035914   98.421290  106.581650   94.628915   99.872166
# 2021-12-31   92.920710   98.716291  106.569996   94.336347   99.869061
# 2022-01-01         NaN         NaN         NaN         NaN         NaN
#
#               JPYUSD=X     ADA-USD     BCH-USD      BNB-USD     BTC-USD  \
# Date
# ...

# %%
BTC = df['BTC-USD'].to_frame()
BTC
# Out:
#                BTC-USD
# Date
# 2018-01-01  100.000000
# 2018-01-02  109.701106
# 2018-01-03  111.303926
# 2018-01-04  114.219606
# 2018-01-05  127.621326
# ...                ...
# 2021-12-28  348.452500
# 2021-12-29  340.074908
# 2021-12-30  345.445072
# 2021-12-31  339.062507
# 2022-01-01  349.169755
#
# [1462 rows x 1 columns]

# %%
BTC.rename(columns={'BTC-USD': 'Norm_Price'}, inplace=True)
BTC
# Out:
#             Norm_Price
# Date
# 2018-01-01  100.000000
# 2018-01-02  109.701106
# 2018-01-03  111.303926
# 2018-01-04  114.219606
# 2018-01-05  127.621326
# ...                ...
# 2021-12-28  348.452500
# 2021-12-29  340.074908
# 2021-12-30  345.445072
# 2021-12-31  339.062507
# 2022-01-01  349.169755
#
# [1462 rows x 1 columns]

# %%
BTC['Cummax'] = BTC['Norm_Price'].cummax()
BTC
# Out:
#             Norm_Price      Cummax
# Date
# 2018-01-01  100.000000  100.000000
# 2018-01-02  109.701106  109.701106
# 2018-01-03  111.303926  111.303926
# 2018-01-04  114.219606  114.219606
# 2018-01-05  127.621326  127.621326
# ...                ...         ...
# 2021-12-28  348.452500  494.734112
# 2021-12-29  340.074908  494.734112
# 2021-12-30  345.445072  494.734112
# 2021-12-31  339.062507  494.734112
# 2022-01-01  349.169755  494.734112
#
# [1462 rows x 2 columns]

# %%
BTC['Drawdown'] = (BTC['Cummax'] - BTC['Norm_Price']) / BTC['Cummax']      # (pos.) drawdown in %      
BTC
# Out:
#             Norm_Price      Cummax  Drawdown
# Date
# 2018-01-01  100.000000  100.000000  0.000000
# 2018-01-02  109.701106  109.701106  0.000000
# 2018-01-03  111.303926  111.303926  0.000000
# 2018-01-04  114.219606  114.219606  0.000000
# 2018-01-05  127.621326  127.621326  0.000000
# ...                ...         ...       ...
# 2021-12-28  348.452500  494.734112  0.295677
# 2021-12-29  340.074908  494.734112  0.312611
# 2021-12-30  345.445072  494.734112  0.301756
# 2021-12-31  339.062507  494.734112  0.314657
# 2022-01-01  349.169755  494.734112  0.294227
#
# [1462 rows x 3 columns]

# %%
BTC['Drawdown'].max()
# Out:
# 0.8153271113852912

# %%
BTC.plot(figsize=(15,10), fontsize=13, secondary_y='Drawdown') 
plt.title('BTC', fontdict={'fontweight': 'bold', 'fontsize': 18})
plt.legend(fontsize=13)
plt.show()

# %%
def max_drawdown(log_ret):
    norm_prices = log_ret.cumsum().apply(np.exp)
    cummax = norm_prices.cummax()
    drawdown = (cummax - norm_prices) / cummax
    max_dd = drawdown.max()
    return max_dd

# %%
log_returns.apply(max_drawdown).sort_values(ascending=False)
# Out:
# ADA-USD     0.978493
# BCH-USD     0.973280
# XLM-USD     0.962687
# XRP-USD     0.958661
# ETH-USD     0.939625
# XMR-USD     0.928134
# LTC-USD     0.920850
# DOGE-USD    0.910054
# BTC-USD     0.815327
# BNB-USD     0.801024
# AUDUSD=X    0.295377
# GBPUSD=X    0.177477
# CADUSD=X    0.170536
# JPYUSD=X    0.168682
# EURUSD=X    0.157848
# CHFUSD=X    0.135136
# USDT-USD    0.075302
# dtype: float64

# %%
def calmar(log_ret):
    max_dd = max_drawdown(log_ret)
    if max_dd == 0:
        return np.nan
    else:
        cagr = np.exp(log_ret.sum()) ** (1 / ((log_ret.index[-1] - log_ret.index[0]).days / 365.25)) - 1
        return cagr / max_dd

# %%
log_returns.apply(calmar).sort_values(ascending=False)
# Out:
# BNB-USD     2.264137
# DOGE-USD    1.207960
# ETH-USD     0.517458
# BTC-USD     0.450090
# ADA-USD     0.176258
# GBPUSD=X    0.069594
# CADUSD=X    0.007024
# USDT-USD   -0.022403
# AUDUSD=X   -0.053586
# XMR-USD    -0.092982
# CHFUSD=X   -0.105092
# EURUSD=X   -0.107604
# LTC-USD    -0.107899
# XLM-USD    -0.133940
# JPYUSD=X   -0.171742
# XRP-USD    -0.237788
# BCH-USD    -0.355709
# dtype: float64

# %%
output['Calmar'] = log_returns.apply(calmar)
output.sort_values('Sharpe', ascending=False)
# Out:
#           Ann_Return  Ann_Risk    Sharpe   Sortino    Calmar
# BNB-USD     1.034475  1.160420  0.891466  1.329195  2.264137
# DOGE-USD    0.741608  1.555965  0.476623  0.867731  1.207960
# BTC-USD     0.312597  0.769040  0.406477  0.554517  0.450090
# ETH-USD     0.396234  0.995160  0.398161  0.538976  0.517458
# GBPUSD=X    0.012276  0.078104  0.157171  0.293302  0.069594
# ADA-USD     0.159110  1.171091  0.135865  0.195862  0.176258
# CADUSD=X    0.001197  0.063424  0.018875  0.036524  0.007024
# USDT-USD   -0.001688  0.083906 -0.020123 -0.028920 -0.022403
# XMR-USD    -0.090252  1.052087 -0.085784 -0.112833 -0.092982
# LTC-USD    -0.104648  1.049906 -0.099674 -0.136243 -0.107899
# XLM-USD    -0.138047  1.171941 -0.117794 -0.172423 -0.133940
# AUDUSD=X   -0.015955  0.085977 -0.185567 -0.341570 -0.053586
# XRP-USD    -0.258716  1.196589 -0.216211 -0.306262 -0.237788
# CHFUSD=X   -0.014304  0.058599 -0.244093 -0.442057 -0.105092
# ...

# %%
df = output.rank(ascending=False).sort_values('Sharpe')
df
# Out:
#           Ann_Return  Ann_Risk  Sharpe  Sortino  Calmar
# BNB-USD          1.0       6.0     1.0      1.0     1.0
# DOGE-USD         2.0       1.0     2.0      2.0     2.0
# BTC-USD          4.0      10.0     3.0      3.0     4.0
# ETH-USD          3.0       9.0     4.0      4.0     3.0
# GBPUSD=X         6.0      13.0     5.0      5.0     6.0
# ADA-USD          5.0       5.0     6.0      6.0     5.0
# CADUSD=X         7.0      14.0     7.0      7.0     7.0
# USDT-USD         8.0      12.0     8.0      8.0     8.0
# XMR-USD         13.0       7.0     9.0      9.0    10.0
# LTC-USD         14.0       8.0    10.0     10.0    13.0
# XLM-USD         15.0       4.0    11.0     11.0    14.0
# AUDUSD=X        10.0      11.0    12.0     13.0     9.0
# XRP-USD         16.0       3.0    13.0     12.0    16.0
# CHFUSD=X         9.0      16.0    14.0     14.0    11.0
# EURUSD=X        11.0      17.0    15.0     16.0    12.0
# BCH-USD         17.0       2.0    16.0     15.0    17.0
# ...

# %% [markdown]
# ### Conclusion:
# The best performing instrument: __Binance Coin (BNB)__.

# %% [markdown]
# ## K-Means Clustering

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=4)

# %%
labels = model.fit_predict(output)
labels
# Out:
# array([3, 3, 3, 3, 3, 3, 1, 0, 2, 1, 2, 1, 0, 3, 0, 0, 0])

# %%
output['Cluster'] = labels
output
# Out:
#           Ann_Return  Ann_Risk    Sharpe   Sortino    Calmar  Cluster
# AUDUSD=X   -0.015955  0.085977 -0.185567 -0.341570 -0.053586        3
# CADUSD=X    0.001197  0.063424  0.018875  0.036524  0.007024        3
# CHFUSD=X   -0.014304  0.058599 -0.244093 -0.442057 -0.105092        3
# EURUSD=X   -0.017131  0.057622 -0.297298 -0.530800 -0.107604        3
# GBPUSD=X    0.012276  0.078104  0.157171  0.293302  0.069594        3
# JPYUSD=X   -0.029398  0.058660 -0.501151 -0.906074 -0.171742        3
# ADA-USD     0.159110  1.171091  0.135865  0.195862  0.176258        1
# BCH-USD    -0.424960  1.223833 -0.347237 -0.477453 -0.355709        0
# BNB-USD     1.034475  1.160420  0.891466  1.329195  2.264137        2
# BTC-USD     0.312597  0.769040  0.406477  0.554517  0.450090        1
# DOGE-USD    0.741608  1.555965  0.476623  0.867731  1.207960        2
# ETH-USD     0.396234  0.995160  0.398161  0.538976  0.517458        1
# ...

# %%
df['Cluster'] = labels
df
# Out:
#           Ann_Return  Ann_Risk  Sharpe  Sortino  Calmar  Cluster
# BNB-USD          1.0       6.0     1.0      1.0     1.0        3
# DOGE-USD         2.0       1.0     2.0      2.0     2.0        3
# BTC-USD          4.0      10.0     3.0      3.0     4.0        3
# ETH-USD          3.0       9.0     4.0      4.0     3.0        3
# GBPUSD=X         6.0      13.0     5.0      5.0     6.0        3
# ADA-USD          5.0       5.0     6.0      6.0     5.0        3
# CADUSD=X         7.0      14.0     7.0      7.0     7.0        1
# USDT-USD         8.0      12.0     8.0      8.0     8.0        0
# XMR-USD         13.0       7.0     9.0      9.0    10.0        2
# LTC-USD         14.0       8.0    10.0     10.0    13.0        1
# XLM-USD         15.0       4.0    11.0     11.0    14.0        2
# AUDUSD=X        10.0      11.0    12.0     13.0     9.0        1
# XRP-USD         16.0       3.0    13.0     12.0    16.0        0
# ...

# %%
label_color_map = {0: 'b', 1: 'g', 2: 'r', 3: 'y'}                  
label_color = [label_color_map[l] for l in labels]

# %%
output.plot(kind='scatter', x='Ann_Risk', y='Ann_Return', figsize=(15,10), s=25, fontsize=13, c=label_color) 
for i in cryp.drop(columns='LTC-USD').columns: 
    plt.annotate(i.replace('-USD', ''), xy=(output.loc[i,'Ann_Risk']+0.01, output.loc[i,'Ann_Return']+0.01), size=13)
plt.annotate('LTC', xy=(output.loc['LTC-USD','Ann_Risk']+0.01, output.loc['LTC-USD','Ann_Return']-0.015), size=13)  
plt.xlabel('Risk (std)', fontsize=15)     
plt.ylabel('Return', fontsize=15)
plt.title('Risk/Return', fontdict={'fontweight': 'bold', 'fontsize': 18})
plt.show()
